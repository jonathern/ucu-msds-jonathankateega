# %%
# Importing packages
import pandas as pd

# %%
# Loading in the CSV
df = pd.read_csv("college_scorecard.csv")
print(df.shape)
df.head()
# Out:
# (500, 21)
#    latest.admissions.admission_rate.overall  latest.cost.tuition.in_state  \
# 0                                    0.6622                       10024.0
# 1                                    0.8842                        8832.0
# 2                                       NaN                           NaN
# 3                                    0.7425                       11770.0
# 4                                    0.9564                       11248.0
#
#    latest.completion.rate_suppressed.lt_four_year_150percent  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    latest.completion.rate_suppressed.four_year  \
# 0                                       0.2772
# 1                                       0.6345
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 21 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   latest.admissions.admission_rate.overall                          163 non-null    float64
#  1   latest.cost.tuition.in_state                                      354 non-null    float64
#  2   latest.completion.rate_suppressed.lt_four_year_150percent         237 non-null    float64
#  3   latest.completion.rate_suppressed.four_year                       194 non-null    float64
#  4   latest.completion.rate_suppressed.lt_four_year                    238 non-null    float64
#  5   latest.completion.rate_suppressed.four_year_200percent            161 non-null    float64
#  6   latest.completion.rate_suppressed.four_year_100_pooled            159 non-null    float64
# ...

# %%
# Trying to make sense of the column names
# Reorganizing the columns
new_order = [
    'id',
    'school.name',
    'school.state',
    'school.city',
    'latest.cost.tuition.in_state',
    'school.ownership',
    
    'location.lat',
    'location.lon'
]
